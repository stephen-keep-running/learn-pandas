# %% [markdown]
# # Pandas数据排序

# %% [markdown]
# Series的排序：<br>
# ***Series.sort_value(ascending=Ture,inplace=Flase)***
# 参数说明：
#    * ascending: 默认为True升序排序，为False降序排序
#    * inplace: 是否修改原始Series
#
# DataFrame的排序:<br>
# ***DataFrame.sort_values(by,ascending=True,inplace=False)***
# 参数说明：
#    * by: 字符串或者List<字符串>，单列排序或者多列排序
#    * ascending: bool或者list,升序还是降序，如果是list对应by的多列
#    * inplace: 是否修改原始DataFrame

# %%
import pandas as pd

# %% [markdown]
# ## 0. 读取数据

# %%
fpath="datas/weather_20230115134249.csv"
df = pd.read_csv(fpath)

# 替换温度的后缀℃
df.loc[:,"气温(度)"] = df["气温(度)"].str.replace("℃","").astype("float")

# %%
df.head()
# Out:
#          日期   城市  行政区  观测站  气温(度)  相对湿度(%)  累积雨量(mm)
# 0  2015-1-1  新北市  烏來區   福山   13.7       92       0.0
# 1  2015-1-2  臺南市  安平區   安平   23.5       70       0.0
# 2  2015-1-3  臺東縣  東河鄉  七塊厝   19.6       86       0.0
# 3  2015-1-4  新北市  貢寮區   福隆   14.2       96     -99.0
# 4  2015-1-5  南投縣  仁愛鄉  小奇萊    8.3       57       0.0

# %% [markdown]
# ## 1. Series的排序

# %%
# 升序排序
df["相对湿度(%)"].sort_values()
# Out:
# 381   -9900
# 162   -9900
# 453   -9900
# 470   -9900
# 24    -9900
# 52    -9900
# 104   -9900
# 286   -9900
# 161   -9900
# 15    -9900
# 186   -9900
# 158   -9900
# 132   -9900
# 218      30
# 440      39
# 438      40
# 142      40
# 150      43
# 420      45
# 86       45
# 163      47
# 84       47
# 198      49
# 204      49
# 273      49
# 23       50
# 293      50
# 337      50
# 12       50
# 417      51
#        ...
# 139     100
# 480     100
# 21      100
# 111     100
# 105     100
# 9       100
# 8       100
# 384     100
# 261     100
# 220     100
# 193     100
# 291     100
# 70      100
# 292     100
# 431     100
# 365     100
# 201     100
# 311     100
# 312     100
# 121     100
# 369     100
# 314     100
# 323     100
# 171     100
# 90      100
# 167     100
# 274     100
# 95      100
# 49      100
# 352     100
# Name: 相对湿度(%), Length: 484, dtype: int64

# %%
# 降序排序
df["相对湿度(%)"].sort_values(ascending=False)
# Out:
# 352     100
# 49      100
# 95      100
# 274     100
# 167     100
# 90      100
# 171     100
# 323     100
# 314     100
# 369     100
# 121     100
# 312     100
# 311     100
# 201     100
# 365     100
# 431     100
# 292     100
# 70      100
# 291     100
# 193     100
# 220     100
# 261     100
# 384     100
# 8       100
# 9       100
# 105     100
# 111     100
# 21      100
# 480     100
# 139     100
#        ...
# 417      51
# 12       50
# 337      50
# 293      50
# 23       50
# 273      49
# 204      49
# 198      49
# 84       47
# 163      47
# 86       45
# 420      45
# 150      43
# 142      40
# 438      40
# 440      39
# 218      30
# 132   -9900
# 158   -9900
# 186   -9900
# 15    -9900
# 161   -9900
# 286   -9900
# 104   -9900
# 52    -9900
# 24    -9900
# 470   -9900
# 453   -9900
# 162   -9900
# 381   -9900
# Name: 相对湿度(%), Length: 484, dtype: int64

# %%
df["行政区"].sort_values()
# Out:
# 286     七堵區
# 329     七股區
# 411    三地門鄉
# 20      三峽區
# 276     三星鄉
# 185     三民區
# 400     三灣鄉
# 469     三義鄉
# 446     三芝區
# 184     三芝區
# 477     三重區
# 18      下營區
# 165     中和區
# 320     中埔鄉
# 413     中壢區
# 467     中寮鄉
# 274     中正區
# 183     中正區
# 288     九如鄉
# 353     二崙鄉
# 229     二林鎮
# 88      二水鄉
# 482     五峰鄉
# 301     五結鄉
# 71      五股區
# 102     仁德區
# 273     仁愛鄉
# 396     仁愛鄉
# 4       仁愛鄉
# 249     仁愛鄉
#        ...
# 29      頭城鎮
# 430     頭城鎮
# 90      頭城鎮
# 424     頭城鎮
# 261     頭城鎮
# 17      頭屋鄉
# 206     香山區
# 81      高樹鄉
# 12      魚池鄉
# 289     鳳山區
# 347     鳳林鎮
# 384     鳳林鎮
# 280     鳳林鎮
# 99      鶯歌區
# 465     鹽埔鄉
# 285     鹽水區
# 113     鹿港鎮
# 444     鹿草鄉
# 397     鹿谷鄉
# 25      鹿野鄉
# 290     鹿野鄉
# 181     麟洛鄉
# 410     麻豆區
# 107     鼓山區
# 415     龍井區
# 194     龍井區
# 468     龍崎區
# 237     龍潭區
# 463     龜山區
# 131     龜山區
# Name: 行政区, Length: 484, dtype: object

# %% [markdown]
# ## 2. DataFrame的排序

# %% [markdown]
# ### 2.1 单列排序

# %%
# 升序排序
df.sort_values(by="相对湿度(%)")
# Out:
#              日期   城市   行政区       观测站  气温(度)  相对湿度(%)  累积雨量(mm)
# 381   2016-1-17  高雄市   梓官區        梓官  -99.0    -9900     -99.0
# 162   2015-6-12  臺中市   烏日區        烏日  -99.0    -9900     -99.0
# 453   2016-3-29  屏東縣   長治鄉        長治  -99.0    -9900       0.0
# 470   2016-4-15  新北市   永和區        永和  -99.0    -9900     -99.0
# 24    2015-1-25  臺中市   西屯區        西屯  -99.0    -9900     -99.0
# 52    2015-2-22  南投縣   仁愛鄉     奇萊稜線A  -99.0    -9900       0.0
# 104   2015-4-15  臺中市   北屯區        大坑   22.8    -9900       0.0
# 286  2015-10-14  基隆市   七堵區        七堵   12.6    -9900      27.0
# 161   2015-6-11  新北市   瑞芳區       鼻頭角  -99.0    -9900       0.5
# 15    2015-1-16  苗栗縣   造橋鄉        造橋  -99.0    -9900     -99.0
# 186    2015-7-6  新北市   汐止區        汐止  -99.0    -9900     -99.0
# 158    2015-6-8  屏東縣   新埤鄉        新埤  -99.0    -9900     -99.0
# 132   2015-5-13  臺南市   西港區        西港  -99.0    -9900       0.0
# 218    2015-8-7  臺中市   和平區     雪山東峰A    9.9       30       0.0
# ...

# %%
# 降序排序
df.sort_values(by="相对湿度(%)",ascending=False)
# Out:
#              日期   城市   行政区       观测站  气温(度)  相对湿度(%)  累积雨量(mm)
# 49    2015-2-19  宜蘭縣   南澳鄉       西德山    9.1      100       4.5
# 392   2016-1-28  宜蘭縣   大同鄉        南山   10.4      100       0.0
# 21    2015-1-22  宜蘭縣   頭城鎮       桃源谷   11.3      100      20.0
# 384   2016-1-20  花蓮縣   鳳林鎮       鳳林山   14.3      100       2.5
# 70    2015-3-12  臺北市   北投區       大屯山    7.3      100       6.0
# 323  2015-11-20  宜蘭縣   大同鄉       鴛鴦湖    9.7      100       0.5
# 201   2015-7-21  新北市   烏來區     福山植物園   13.5      100       0.5
# 139   2015-5-20  宜蘭縣   礁溪鄉  淡江大學蘭陽校園   14.5      100       0.0
# 121    2015-5-2  新北市   汐止區       五指山   10.1      100      18.5
# 431    2016-3-7  宜蘭縣   南澳鄉       西帽山   11.1      100      24.5
# 111   2015-4-22  花蓮縣   光復鄉        富源   16.5      100       1.0
# 193   2015-7-13  新北市   萬里區        大坪   11.0      100      87.0
# 274   2015-10-2  基隆市   中正區       基隆嶼   12.8      100       7.5
# 399    2016-2-4  臺東縣   大武鄉       山豬窟   19.0      100       0.0
# ...

# %% [markdown]
# ### 2.2 多列排序

# %%
# 按湿度、温度排序，默认升序
df.sort_values(by=["相对湿度(%)","气温(度)"])
# Out:
#              日期   城市   行政区       观测站  气温(度)  相对湿度(%)  累积雨量(mm)
# 15    2015-1-16  苗栗縣   造橋鄉        造橋  -99.0    -9900     -99.0
# 24    2015-1-25  臺中市   西屯區        西屯  -99.0    -9900     -99.0
# 52    2015-2-22  南投縣   仁愛鄉     奇萊稜線A  -99.0    -9900       0.0
# 132   2015-5-13  臺南市   西港區        西港  -99.0    -9900       0.0
# 158    2015-6-8  屏東縣   新埤鄉        新埤  -99.0    -9900     -99.0
# 161   2015-6-11  新北市   瑞芳區       鼻頭角  -99.0    -9900       0.5
# 162   2015-6-12  臺中市   烏日區        烏日  -99.0    -9900     -99.0
# 186    2015-7-6  新北市   汐止區        汐止  -99.0    -9900     -99.0
# 381   2016-1-17  高雄市   梓官區        梓官  -99.0    -9900     -99.0
# 453   2016-3-29  屏東縣   長治鄉        長治  -99.0    -9900       0.0
# 470   2016-4-15  新北市   永和區        永和  -99.0    -9900     -99.0
# 286  2015-10-14  基隆市   七堵區        七堵   12.6    -9900      27.0
# 104   2015-4-15  臺中市   北屯區        大坑   22.8    -9900       0.0
# 218    2015-8-7  臺中市   和平區     雪山東峰A    9.9       30       0.0
# ...

# %%
# 两个字段都是降序
df.sort_values(by=["相对湿度(%)","气温(度)"],ascending=False)
# Out:
#              日期   城市   行政区       观测站  气温(度)  相对湿度(%)  累积雨量(mm)
# 167   2015-6-17  彰化縣   芳苑鄉        芳苑   19.5      100       0.0
# 399    2016-2-4  臺東縣   大武鄉       山豬窟   19.0      100       0.0
# 291  2015-10-19  花蓮縣   玉里鎮        德武   17.8      100       1.5
# 292  2015-10-20  花蓮縣   瑞穗鄉        舞鶴   16.8      100       1.0
# 111   2015-4-22  花蓮縣   光復鄉        富源   16.5      100       1.0
# 312   2015-11-9  花蓮縣   壽豐鄉       蕃薯寮   16.1      100       5.5
# 369    2016-1-5  花蓮縣   玉里鎮       安通山   16.1      100       0.0
# 95     2015-4-6  臺東縣   達仁鄉       勝林山   15.9      100       0.0
# 365    2016-1-1  臺東縣  太麻里鄉       金崙山   15.3      100       0.0
# 139   2015-5-20  宜蘭縣   礁溪鄉  淡江大學蘭陽校園   14.5      100       0.0
# 384   2016-1-20  花蓮縣   鳳林鎮       鳳林山   14.3      100       2.5
# 344  2015-12-11  新北市   貢寮區       三貂角   14.1      100       3.0
# 401    2016-2-6  花蓮縣   秀林鄉        水源   14.1      100       3.5
# 171   2015-6-21  花蓮縣   豐濱鄉      加路蘭山   13.7      100       5.5
# ...

# %%
#分别指定升序和降序
df.sort_values(by=["相对湿度(%)","气温(度)"],ascending=[True,False])
# Out:
#              日期   城市   行政区       观测站  气温(度)  相对湿度(%)  累积雨量(mm)
# 104   2015-4-15  臺中市   北屯區        大坑   22.8    -9900       0.0
# 286  2015-10-14  基隆市   七堵區        七堵   12.6    -9900      27.0
# 15    2015-1-16  苗栗縣   造橋鄉        造橋  -99.0    -9900     -99.0
# 24    2015-1-25  臺中市   西屯區        西屯  -99.0    -9900     -99.0
# 52    2015-2-22  南投縣   仁愛鄉     奇萊稜線A  -99.0    -9900       0.0
# 132   2015-5-13  臺南市   西港區        西港  -99.0    -9900       0.0
# 158    2015-6-8  屏東縣   新埤鄉        新埤  -99.0    -9900     -99.0
# 161   2015-6-11  新北市   瑞芳區       鼻頭角  -99.0    -9900       0.5
# 162   2015-6-12  臺中市   烏日區        烏日  -99.0    -9900     -99.0
# 186    2015-7-6  新北市   汐止區        汐止  -99.0    -9900     -99.0
# 381   2016-1-17  高雄市   梓官區        梓官  -99.0    -9900     -99.0
# 453   2016-3-29  屏東縣   長治鄉        長治  -99.0    -9900       0.0
# 470   2016-4-15  新北市   永和區        永和  -99.0    -9900     -99.0
# 218    2015-8-7  臺中市   和平區     雪山東峰A    9.9       30       0.0
# ...
